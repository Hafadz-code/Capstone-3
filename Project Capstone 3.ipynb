# %% [markdown]
# # BACKGROUND

# %% [markdown]
# Hunian adalah bagian yang tidak terpisahkan dari kehidupan manusia. Maslow dalam teori hierarchy of needs (1954) mengkategorikan kebutuhan hunian sebagai salah satu kebutuhan fisiologis paling dasar yang harus dipenuhi manusia sebelum kebutuhan-kebutuhan lainnya. Kebutuhan terhadap tempat tinggal menjadi kebutuhan seluruh manusia untuk bernaung dan beraktifitas. Perbedaan kebutuhan manusia dalam hunian memunculkan berbagai jenis hunian mulai dari hunian tapak sampai dengan hunian vertikal. Apartemen atau dikenal juga dengan hunian vertikal menjadi salah satu bentuk hunian yang akan memenuhi kebutuhan tempat tinggal manusia. Permintaan kebutuhan rumah tinggal bagi masyarakat kota besar yang semakin padat tidak dipenuhi dengan ketersediaan lahan dan rumah. Salah satu cara untuk mengefektifkan penggunaan lahan dan mengkonsentrasikan pertumbuhan penduduk adalah mengembangkan area-area yang kompak dengan kepadatan tinggi namun tetap memenuhi kebutuhan masyarakat dengan baik (Shi, L.,Yang, S.,& Gao, L., 2016); (Wong, 2004). Oleh karena itu, hunian vertikal dianggap menjadi solusi dalam mengatasi masalah kebutuhan hunian masyarakat terhadap hunian.
#
# Saat ini kelompok usia dewasa muda menjadi kelompok usia paling mendominasi dibandingkan kelompok usia lainnya (Statistik, 2021). Kelompok usia inilah yang dijadikan target pasar hunian karena minat yang cukup tinggi dalam memiliki hunian. Masyarakat dengan kelompok usia ini tentunya memiliki kebutuhan dan pertimbangan tertentu dalam memilih jenis hunian. Secara umum, ditemukan bahwa harga apartemen, aksesibilitas, dan kemampuan ekonomi calon pembeli menjadi faktor determinan dalam preferensi memilih apartemen (Fardiansyah, 2017); (Cahyani, 2012). Selain menemukan bahwa preferensi hunian ini juga dipengaruhi oleh ukuran dan tipe unit, kualitas, lokasi, lingkungan tempat tinggal, dan adanya fasilitas publik. Selain itu, studi lainnya menyatakan bahwa generasi Y (kelahiran tahun 1981-1994) mempertimbangkan faktor kelengkapan fasilitas seperti laundry dan fasilitas penitipan anak dalam memilih apartemen juga keterjangkauan harga dan pilihan sistem pembayaran (Nadiya, 2017).
#
# Perorangan atau perusahaan biasanya membuat penawaran apartemen (unit). Peserta lelang dapat menjual unit di platform dengan menentukan harga apartemen mereka. Cara itu cukup sulit bagi pemilik apartemen untuk menyesuaikan dengan harga pasar. Jika harganya terlalu tinggi dibandingkan dengan harga pasar, tentu akan sulit untuk melakukan penjualan. Sebaliknya, jika terlalu rendah, pemilik akan kesulitan untuk mendapatkan keuntungan yang maksimal.
#
# Daegu merupakan bekas ibu kota provinsi Gyeongsang dari tahun 1392 hingga tahun 1896. Pada tahun 1980-an, Daegu menjadi Kota Khusus Korea atau Kota yang Diperintah Langsung (Jikhalsi) tingkat provinsi yang dikelola secara terpisah, dan didesain ulang menjadi Kota Metropolitan (Gwangyeoksi) pada tahun 1995.
#
# Daegu adalah kota terbesar di wilayah Gyeongsang Utara. Selama Dinasti Joseon, kota ini menjadi pusat administratif, ekonomi, dan budaya seluruh wilayah Gyeongsang, yang sebagian besar perannya sekarang diambil alih oleh Busan di Gyeongsang Selatan. Saat ini, Daegu merupakan wilayah metropolitan terbesar ke-4 dalam hal populasi, dan masih menjadi kota perdagangan terbesar ke-3 di Korea Selatan.

# %% [markdown]
#  # BUSINESS PROBLEM

# %% [markdown]
# ## 1.	Mengapa menggunakan Machine Learning untuk menetukan prediksi harga apartment?

# %% [markdown]
# Penentuan harga penjualan apartemen di Daegu banyak dipengaruhi oleh beberapa atribut atau spesifikasi dari aset tersebut, misalnya: Jenis lorong pada apartemen, durasi waktu ke stasiun kereta bawah tanah, nama stasiun kereta bawah tanah, jumlah fasilitas yang terdekat (ETC), jumlah fasilitas kantor publik, jumlah universitas terdekat, jumlah tempat parkir basement, tahun pembangunan apartemen, jumlah fasilitas apartemen yang ditawarkan dalam aplikasi/platform serta luasan apartemen. Hal inilah yang menyebabkan proses prediksi harga akan menjadi lama. Disinilah Machine Learning berperan untuk mempermudah proses prediksi harga jual apartemen. Salah satu peran dalam Machine Learning adalah kemampuan untuk belajar dari data transaksi sebelumnya dan ini akan menjadi model yang akan dapat digunakan untuk memberikan prediksi harga jual apartemen.

# %% [markdown]
# ## 2.	Market opportunity penjualan apartment di Daegu

# %% [markdown]
# Berdasarkan fakta Saat ini bahwa Daegu merupakan wilayah metropolitan terbesar ke-4 dalam hal populasi dan masih menjadi kota perdagangan terbesar ke-3 di Korea Selatan selain itu, kelompok usia dewasa muda menjadi kelompok usia paling mendominasi dibandingkan kelompok usia lainnya dan Kelompok usia inilah yang dijadikan target pasar hunian karena minat yang cukup tinggi dalam memiliki hunian sehingga pangsa pasar dan permintaan terhadap kepemilikan apartemen juga tinggi.

# %% [markdown]
# ## 3. Permasalahan penjualan apartment di Daegu

# %% [markdown]
# Problem Statement: Individu atau perusahaan biasanya membuat penawaran apartemen (unit). Penawar dapat menjual unit di sebuah platform dengan menentukan harga apartemen mereka. Dengan begitu cukup sulit bagi pemilik apartemen untuk menyesuaikan dengan harga pasar. Jika harganya terlalu tinggi dibandingkan dengan harga pasar, tentu akan sulit untuk melakukan penjualan. Sebaliknya, jika terlalu rendah, pemilik akan sulit mendapatkan keuntungan yang maksimal. (sumber: Dok.Purwadhika)

# %% [markdown]
# ## 4.	Goals (Resolution)

# %% [markdown]
# Berdasarkan permasalahan tersebut, akan dibuatkan sebuah model Machine Learning yang bertujuan untuk mendapatkan prediksi harga yang paling memadai, lebih cepat dan dapat diandalkan agar menjadi referensi harga yang memberikan keuntungan maksimal bagi penjual aset apartemen berdasarkan fitur-fitur yang relevan. Model ini akan dinilai menggunakan Mean Absolut Error (MAE), dengan target MAE kurang dari 50.000 Won. Stakeholder utama adalah agen real estat yang mencari estimasi harga yang dapat diandalkan untuk transaksi properti di Daegu, Kor-sel.

# %% [markdown]
# # DATA UNDERSTANDING & DATA CLEANING

# %% [markdown]
# 1. Memuat data set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
import io
upload_files = files.upload()
# Out:
#      <input type="file" id="files-2182875a-7731-49d5-9d81-202035c8a5a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2182875a-7731-49d5-9d81-202035c8a5a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('data_daegu_apartment.csv')
display(df.head())
# Out:
#   HallwayType TimeToSubway          SubwayStation  N_FacilitiesNearBy(ETC)  \
# 0    terraced       0-5min  Kyungbuk_uni_hospital                      0.0
# 1    terraced  10min~15min  Kyungbuk_uni_hospital                      1.0
# 2       mixed  15min~20min       Chil-sung-market                      1.0
# 3       mixed   5min~10min                Bangoge                      5.0
# 4    terraced       0-5min                Sin-nam                      0.0
#
#    N_FacilitiesNearBy(PublicOffice)  N_SchoolNearBy(University)  \
# 0                               3.0                         2.0
# 1                               5.0                         1.0
# 2                               7.0                         3.0
# 3                               5.0                         4.0
# 4                               1.0                         2.0
#
#    N_Parkinglot(Basement)  YearBuilt  N_FacilitiesInApt  Size(sqf)  SalePrice
# ...

# %%
listItem = []
for col in df.columns :
    listItem.append([col, df[col].dtype, df[col].isna().sum(), round((df[col].isna().sum()/len(df[col])) * 100,2),
                    df[col].nunique(), list(df[col].drop_duplicates().sample(2).values)]);

dfDesc = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null', 'nullPct', 'unique', 'uniqueSample'],
                     data=listItem)
dfDesc
# Out:
#                         dataFeatures dataType  null  nullPct  unique  \
# 0                        HallwayType   object     0      0.0       3
# 1                       TimeToSubway   object     0      0.0       5
# 2                      SubwayStation   object     0      0.0       8
# 3            N_FacilitiesNearBy(ETC)  float64     0      0.0       4
# 4   N_FacilitiesNearBy(PublicOffice)  float64     0      0.0       8
# 5         N_SchoolNearBy(University)  float64     0      0.0       6
# 6             N_Parkinglot(Basement)  float64     0      0.0      20
# 7                          YearBuilt    int64     0      0.0      16
# 8                  N_FacilitiesInApt    int64     0      0.0       9
# 9                          Size(sqf)    int64     0      0.0      89
# 10                         SalePrice    int64     0      0.0     838
#
#                                  uniqueSample
# 0                           [terraced, mixed]
# 1                   in~20min, 5min~10min]
# ...

# %%
pd.set_option('display.max_colwidth', 1)
listItem = []
for col in df.columns :
    listItem.append( [col, df[col].nunique(), df[col].unique()])

tabel1Desc = pd.DataFrame(columns=['Column Name', 'Number of Unique', 'Unique Value'],
                     data=listItem)
tabel1Desc
# Out:
#                          Column Name  Number of Unique  \
# 0   HallwayType                       3
# 1   TimeToSubway                      5
# 2   SubwayStation                     8
# 3   N_FacilitiesNearBy(ETC)           4
# 4   N_FacilitiesNearBy(PublicOffice)  8
# 5   N_SchoolNearBy(University)        6
# 6   N_Parkinglot(Basement)            20
# 7   YearBuilt                         16
# 8   N_FacilitiesInApt                 9
# 9   Size(sqf)                         89
# 10  SalePrice                         838
#
# ...

# %%
df['HallwayType'].unique()
# Out:
# array(['terraced', 'mixed', 'corridor'], dtype=object)

# %%
df['TimeToSubway'].unique()
# Out:
# array(['0-5min', '10min~15min', '15min~20min', '5min~10min',
#        'no_bus_stop_nearby'], dtype=object)

# %%
df['SubwayStation'].unique()
# Out:
# array(['Kyungbuk_uni_hospital', 'Chil-sung-market', 'Bangoge', 'Sin-nam',
#        'Banwoldang', 'no_subway_nearby', 'Myung-duk', 'Daegu'],
#       dtype=object)

# %%
df['N_FacilitiesNearBy(ETC)'].unique()
# Out:
# array([0., 1., 5., 2.])

# %%
df['N_FacilitiesNearBy(PublicOffice)'].unique()
# Out:
# array([3., 5., 7., 1., 4., 2., 6., 0.])

# %%
df['N_SchoolNearBy(University)'].unique()
# Out:
# array([2., 1., 3., 4., 5., 0.])

# %%
df['N_Parkinglot(Basement)'].unique()
# Out:
# array([1270.,    0.,   56.,  798.,  536.,  605.,  203.,  108., 1174.,
#         930.,  475.,  184.,  400.,  218., 1321.,  524.,   76.,   79.,
#         181.,   18.])

# %%
df['YearBuilt'].unique()
# Out:
# array([2007, 1986, 1997, 2005, 2006, 2009, 2014, 1993, 2013, 2008, 2015,
#        1978, 1985, 1992, 2003, 1980])

# %%
df['N_FacilitiesInApt'].unique()
# Out:
# array([10,  4,  5,  7,  2,  9,  8,  1,  3])

# %%
df['Size(sqf)'].unique()
# Out:
# array([1387,  914,  558, 1743, 1334,  572,  910,  288, 1131,  843, 1160,
#         644,  829,  743,  868, 1629, 1690, 1273, 1483,  156, 1412, 1394,
#         903,  676,  355, 1419,  640, 1184, 1167,  135,  818,  206, 1643,
#         907, 1377, 2337, 1252,  451,  587,  811, 2056,  508,  576, 1366,
#        1103,  426,  281, 1327, 1092,  857, 1928, 1149, 1088, 1288, 1761,
#        1437, 1291, 2092,  636,  814,  871, 1519, 1444, 1451, 1448, 1313,
#        1256, 1796, 1192, 1035,  846,  273,  277,  779,  498,  736,  138,
#         430,  213,  163, 1369,  192,  547,  839,  160,  793, 1085, 1060,
#         832])

# %%
df['SalePrice'].unique()
# Out:
# array([346017, 150442,  61946, 165486, 311504, 118584, 326548, 143362,
#        172566,  99823, 211504, 305309, 145132, 209734, 168141, 144752,
#        389380, 347787, 263345, 207079, 149274, 200000,  85132, 245132,
#        256637, 207964, 371681, 442477, 435398,  75920, 280530, 163716,
#        263716, 286725, 138938,  57522, 302654, 391150, 215176,  75221,
#        476106, 241592, 411504, 123008, 115929, 269026, 348672, 295575,
#        309292,  77876, 345132, 323893, 198230, 372566, 164601, 109734,
#        247787, 158407, 126548, 146017, 203539, 161946, 183628, 195575,
#        331858, 138053, 218584, 380530, 277876,  63274, 258079, 231415,
#        141150, 250176,  56637, 242035, 432743, 274336,  74256,  84955,
#        147761, 143389, 130973,  79646, 151327, 295460,  72920, 495575,
#         89380, 353982, 285840, 228318, 469026, 324778, 243362, 343362,
#        159292, 265486, 318584, 460176,  53097, 376106, 147141,  66371,
# ...

# %% [markdown]
# 2. Data Cleaning & Preprosessing (handling missing value, handling data duplikasi, handling outliers)

# %% [markdown]
# mencari data yang kosong

# %%
df.isna().sum()
# Out:
# HallwayType                         0
# TimeToSubway                        0
# SubwayStation                       0
# N_FacilitiesNearBy(ETC)             0
# N_FacilitiesNearBy(PublicOffice)    0
# N_SchoolNearBy(University)          0
# N_Parkinglot(Basement)              0
# YearBuilt                           0
# N_FacilitiesInApt                   0
# Size(sqf)                           0
# SalePrice                           0
# dtype: int64

# %% [markdown]
# Tidak ditemukan data yang kosong (missing value).
#
# Selanjutnya dilakukan handling data duplikasi

# %%
df.duplicated().any()
# Out:
# True

# %%
df = df.drop_duplicates()

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# Data yang masih ada terduplikasi telah dihapus.
#
# Selanjutnya dilakukan pemeriksaan Outliers dan melakukan handling outliers.

# %%
def rumus_outlier(x):
    q1 = np.percentile(x, 25)
    q3 = np.percentile(x, 75)

    iqr = q3 - q1
    limit = iqr*1.5
    print(f'IQR: {iqr}')
    lower_outlier = q1 - (iqr * 1.5)
    upper_outlier = q3 + (iqr * 1.5)
    print(f'Batas bawah: {lower_outlier}')
    print(f'Batas atas: {upper_outlier}')
    outliers = x[(x < lower_outlier) | (x > upper_outlier)]
    return outliers

# %%
cek_ouliers = {}
for num_feature in df.select_dtypes(['float','int']):
    outliers = rumus_outlier(df[num_feature])
    if len(outliers):
        print(f"Kolom: {num_feature} memiliki {len(outliers)} outlier")
        cek_ouliers[num_feature] = outliers
        outlier_percentage = (len(outliers) / len(df)) * 100
        print(f"Persentase Outlier {num_feature}: {outlier_percentage:.2f}%")
    else:
        print(f"Kolom: {num_feature} tidak memilik outlier.")
        cek_ouliers[num_feature] = None
# Out:
# IQR: 5.0
# Batas bawah: -7.5
# Batas atas: 12.5
# Kolom: N_FacilitiesNearBy(ETC) tidak memilik outlier.
# IQR: 2.0
# Batas bawah: 0.0
# Batas atas: 8.0
# Kolom: N_FacilitiesNearBy(PublicOffice) tidak memilik outlier.
# IQR: 2.0
# Batas bawah: -1.0
# Batas atas: 7.0
# Kolom: N_SchoolNearBy(University) tidak memilik outlier.
# IQR: 617.0
# Batas bawah: -744.5
# Batas atas: 1723.5
# Kolom: N_Parkinglot(Basement) tidak memilik outlier.
# IQR: 14.0
# Batas bawah: 1972.0
# Batas atas: 2028.0
# Kolom: YearBuilt tidak memilik outlier.
# IQR: 3.0
# Batas bawah: -0.5
# Batas atas: 11.5
# Kolom: N_FacilitiesInApt tidak memilik outlier.
# IQR: 424.0
# Batas bawah: 107.0
# Batas atas: 1803.0
# Kolom: Size(sqf) memiliki 84 outlier
# Persentase Outlier Size(sqf): 3.11%
# IQR: 147345.0
# Batas bawah: -67478.5
# Batas atas: 521901.5
# Kolom: SalePrice memiliki 17 outlier
# Persentase Outlier SalePrice: 0.63%

# %% [markdown]
# Dari hasil diatas terlihat terdapat outliers pada kolom Size(sqf): 3.11 % dan SalesPrice: 0.63 %
#
# Selanjutnya memeriksan nilai dari kolom Size(sqf) dan SalesPrice apakah terdapat value yang bernilai = 0

# %%
# tidak ada nilai size dan saleprice yang 0
(df['Size(sqf)'].unique()==0).any()
# Out:
# False

# %%
(df['SalePrice'].unique()==0).any()
# Out:
# False

# %% [markdown]
# Dari hasil diatas tidak ditemukan nilai value yang 0 untuk kedua kolom.
#
# Selanjutnya, dilakukan penggambaran outliers dengan visualisasi

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.boxplot(df['Size(sqf)'],orient='h')
plt.subplot(1,2,2)
sns.boxplot(df['SalePrice'],orient='h')
plt.show()

# %%
# grafik yang menunjukan sebaran outlier pada garis regresi linear
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Size(sqf)', y='SalePrice', data=df)
sns.regplot(x='Size(sqf)', y='SalePrice', data=df, scatter=False, color='green')
plt.title('Scatter Plot dengan Garis Regresi Linear')
plt.xlabel('Size(sqf)')
plt.ylabel('SalePrice')
plt.show()

# %% [markdown]
# Dari kedua visual diatas dapat dilihat perlu adanya penghapusan outliers yang tidak sesuai dengan prinsip bisnis yaitu pada tingginya nilai luasan (Size) tetapi memiliki nilai harga (SalesPrice) yang lebih rendah. hal ini terlihat pada luasan 2000 keatas.
#
# Selanjutnya, perlu melakukan handling outliers dengan menghapus informasi yang tidak sesuai dengan prinsip bisnis tersebut namun sebelumnya perlu untuk mengcopy data sebelum menghapus data yang original sehingga jika diperlukan penyesuaian handling outlier kembali maka data original masih tersimpan dan belum berubah

# %%
df
# Out:
#      HallwayType TimeToSubway          SubwayStation  N_FacilitiesNearBy(ETC)  \
# 0     terraced    0-5min       Kyungbuk_uni_hospital  0.0
# 1     terraced    10min~15min  Kyungbuk_uni_hospital  1.0
# 2     mixed       15min~20min  Chil-sung-market       1.0
# 3     mixed       5min~10min   Bangoge                5.0
# 4     terraced    0-5min       Sin-nam                0.0
# ...        ...       ...           ...                ...
# 4116  terraced    0-5min       Sin-nam                0.0
# 4117  mixed       15min~20min  Myung-duk              5.0
# 4118  terraced    0-5min       Sin-nam                0.0
# 4119  mixed       15min~20min  Myung-duk              5.0
# 4121  corridor    5min~10min   Daegu                  2.0
#
#       N_FacilitiesNearBy(PublicOffice)  N_SchoolNearBy(University)  \
# 0     3.0                               2.0
# 1     5.0                               1.0
# 2     7.0                               3.0
# ...

# %%
# salin df ke untuk mempertahankan data awal sebelum ada perubahan karena handling data, Feature Selection dan Engineering
g = df.copy()

# %% [markdown]
# Penghapusan Outliers dan menampilkan kembali

# %%
g = g.drop(g[g['Size(sqf)'] > 2000].index)
cek_hasil=g['Size(sqf)'].unique()
display(f'{sorted(cek_hasil, reverse=True)}')
# Out:
# '[1928, 1796, 1761, 1743, 1690, 1643, 1629, 1519, 1483, 1451, 1448, 1444, 1437, 1419, 1412, 1394, 1387, 1377, 1369, 1366, 1334, 1327, 1313, 1291, 1288, 1273, 1256, 1252, 1192, 1184, 1167, 1160, 1149, 1131, 1103, 1092, 1088, 1085, 1060, 1035, 914, 910, 907, 903, 871, 868, 857, 846, 843, 839, 832, 829, 818, 814, 811, 793, 779, 743, 736, 676, 644, 640, 636, 587, 576, 572, 558, 547, 508, 498, 451, 430, 426, 355, 288, 281, 277, 273, 213, 206, 192, 163, 160, 156, 138, 135]'

# %%
fig, axes = plt.subplots(1,2, figsize=(20, 5))
sns.distplot(df['Size(sqf)'], ax=axes[0])
sns.distplot(g['Size(sqf)'], ax=axes[1])
axes[0].set_xlabel('Size(sqf) Sebelum')
axes[1].set_xlabel('Size(sqf) Sesudah');

# %% [markdown]
# Khusus pada outlier SalePrice tidak ada yang di hapus karena persentase outliers hanya dibawah 1% (0.63%) dari total 2646 data sehingga outliers tersebut diharapkan masih memiliki informasi yang dapat berguna dalam pemodelan

# %% [markdown]
# Menampilkan data set kembali setelah Data Cleaning

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2646 entries, 0 to 4121
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   HallwayType                       2646 non-null   object
#  1   TimeToSubway                      2646 non-null   object
#  2   SubwayStation                     2646 non-null   object
#  3   N_FacilitiesNearBy(ETC)           2646 non-null   float64
#  4   N_FacilitiesNearBy(PublicOffice)  2646 non-null   float64
#  5   N_SchoolNearBy(University)        2646 non-null   float64
#  6   N_Parkinglot(Basement)            2646 non-null   float64
#  7   YearBuilt                         2646 non-null   int64
#  8   N_FacilitiesInApt                 2646 non-null   int64
#  9   Size(sqf)                         2646 non-null   int64
#  10  SalePrice                         2646 non-null   int64
# dtypes: float64(4), int64(4), object(3)
# ...

# %% [markdown]
# Ringkasan Statistik deskriptif

# %%
g.describe()
# Out:
#        N_FacilitiesNearBy(ETC)  N_FacilitiesNearBy(PublicOffice)  \
# count  2646.00000               2646.000000
# mean   1.88133                  4.032502
# std    2.14738                  1.875844
# min    0.00000                  0.000000
# 25%    0.00000                  3.000000
# 50%    1.00000                  4.000000
# 75%    5.00000                  5.000000
# max    5.00000                  7.000000
#
#        N_SchoolNearBy(University)  N_Parkinglot(Basement)    YearBuilt  \
# count  2646.000000                 2646.000000             2646.000000
# mean   2.670446                    535.320106              2002.461073
# std    1.499670                    421.526892              9.152592
# min    0.000000                    0.000000                1978.000000
# 25%    2.000000                    181.000000              1993.000000
# 50%    2.000000                    536.000000              2006.000000
# ...

# %%
sns.pairplot(g)

# %%
g
# Out:
#      HallwayType TimeToSubway          SubwayStation  N_FacilitiesNearBy(ETC)  \
# 0     terraced    0-5min       Kyungbuk_uni_hospital  0.0
# 1     terraced    10min~15min  Kyungbuk_uni_hospital  1.0
# 2     mixed       15min~20min  Chil-sung-market       1.0
# 3     mixed       5min~10min   Bangoge                5.0
# 4     terraced    0-5min       Sin-nam                0.0
# ...        ...       ...           ...                ...
# 4116  terraced    0-5min       Sin-nam                0.0
# 4117  mixed       15min~20min  Myung-duk              5.0
# 4118  terraced    0-5min       Sin-nam                0.0
# 4119  mixed       15min~20min  Myung-duk              5.0
# 4121  corridor    5min~10min   Daegu                  2.0
#
#       N_FacilitiesNearBy(PublicOffice)  N_SchoolNearBy(University)  \
# 0     3.0                               2.0
# 1     5.0                               1.0
# 2     7.0                               3.0
# ...

# %% [markdown]
# # FEATURE SELECTION & FEATURE ENGINEERING

# %%
h = g.copy() # untuk melihat korelasi (terdapat encoding label_encoders)
i = g.copy() # untuk melihat rasio korelasi
j = g.copy() # untuk melakukan drop column data yang akan dilanjutkan ke Modelling, Evaluation hingga akhir

# %% [markdown]
# ## Feature Selection
#
# Feature Selection
# Variabel input yang diberikan kedalam model machine learning berupa kolom data disebut dengan fitur. Untuk mendapatkan model yang optimal, kita perlu memastikan bahwa kita hanya menggunakan fitur-fitur yang penting. Metode memilih fitur penting dari data disebut dengan Feature Selection. Dalam case ini Feature selection dilakukan dengan menggunakan 3 metode yakni :
#
# Korelasi
# Korelasi digunakan untuk menyatakan keterkaitan fitur numerikal dengan variabel target yang juga numerikal. Namun, korelasi bukanlah kausalitas (Hubungan sebab akibat). Untuk korelasi yang digunakan dalam case ini adalah korelasi Spearmann dikarenakan tidak memiliki syarat berdistribusi normal. Hal ini cocok dengan dataset yang digunakan karena setiap kolomnya tidak berdistribusi dengan normal. Korelasi memiliki range dari -1 sampai dengan 1. Korelasi positif menunjukkan bahwa kedua nilai kolom data searah atau linier (Nilai dari 0 sampai dengan 1), sedangkan korelasi negatif menunjukkan bahwa kedua nilai kolom data berlawanan arah (Nilai dari 0 sampai dengan -1).
#
# Korelasi Ratio
# Korelasi Ratio digunakan untuk menyatakan keterkaitan fitur kategorikal dengan variabel target numerikal. Untuk korelasi yang digunakan dalam case ini adalah korelasi Spearmann dikarenakan tidak memiliki syarat berdistribusi normal. Hal ini cocok dengan dataset yang digunakan karena setiap kolomnya tidak berdistribusi dengan normal. Korelasi ratio memiliki range dari 0 sampai dengan 1.

# %% [markdown]
# ### Korelasi

# %% [markdown]
# Dari data set yang ada akan terdapat error (ValueError: could not convert string to float: 'terraced') jika kita langsung melakukan coding jika ada kolom kategorikal kedalam heatmap correlation numerikal. sehingga kita harus mengonversi data type object kedalam bentuk numerik untuk dapat secara sekaligus menggambarkan Heatmap Correlation secara bersamaan (kategorik & Numerik). Selain itu, Karena masih terdapat beberapa outlier di data SalePrice dan Size(sqf) maka digunakan metode Spearman dalam heatmap korelasi

# %% [markdown]
# #### Encoding Laber Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoders = {}
for column in h.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    h[column] = label_encoders[column].fit_transform(h[column])

# %%
h
# Out:
#       HallwayType  TimeToSubway  SubwayStation  N_FacilitiesNearBy(ETC)  \
# 0     2            0             4              0.0
# 1     2            1             4              1.0
# 2     1            2             2              1.0
# 3     1            3             0              5.0
# 4     2            0             6              0.0
# ...  ..           ..            ..              ...
# 4116  2            0             6              0.0
# 4117  1            2             5              5.0
# 4118  2            0             6              0.0
# 4119  1            2             5              5.0
# 4121  0            3             3              2.0
#
#       N_FacilitiesNearBy(PublicOffice)  N_SchoolNearBy(University)  \
# 0     3.0                               2.0
# 1     5.0                               1.0
# 2     7.0                               3.0
# 3     5.0                               4.0
# 4     1.0                               2.0
# ...

# %%
# Membuat heatmap
plt.figure(figsize=(20, 20))
ax = sns.heatmap(h.corr(method='spearman'), annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
plt.figure(figsize=(20,20))
ax = sns.heatmap(h.corr(method='spearman').sort_values('SalePrice', ascending=False)[['SalePrice']][1:], annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (10.5, -0.5)

# %% [markdown]
# pada heatmap diatas dapat dilihat bahwa feature SubwayStation memiliki nilai korelasi -0,039 atau mendekati nilai 0. nilai ini dapat diartikan bahwa hampir tidak ada korelasi dengan penentuan harga (SalePrice) karena nilai yang paling jauh dari nilai 1 (berkorelasi positif) dan nilai -1 (berkorelasi negatif) dibanding semua feature

# %% [markdown]
# ### Korelasi Rasio

# %%
# !pip install dython

# %%
from dython.nominal import correlation_ratio

# %%
col = i.select_dtypes(include=['object']).columns  # Pilih kolom dengan tipe data objek
ratios = {}

for column in col:
    ratio = correlation_ratio(i[column], i['SalePrice'])
    if not pd.isna(ratio):  # Pastikan rasio bukan NaN
        ratios[column] = ratio

# Periksa apakah `ratios` tidak kosong
if not ratios:
  raise ValueError("Tidak ada kolom kategorikal dengan rasio korelasi yang valid")

i_ratio = pd.DataFrame(ratios, index=['SalePrice'])

# %%
if not i_ratio.empty:  # Pastikan DataFrame tidak kosong
    plt.figure(figsize=(10, 1))
    sns.heatmap(i_ratio, annot=True, cbar=False)
    plt.show()
else:
    print("DataFrame i_ratio kosong, tidak bisa membuat heatmap.")

# %% [markdown]
# Pada korelasi rasio juga menunjukan bahwa SubwayStation memiliki nilai korelasi rasio paling rendah dibandingkan semua kategori
#
# dari kedua hal ini maka dapat menjadi dasar untuk menghapus kolom SubwayStation. selain itu, yang menjadi pertimbangan dalam menentukan pembelian apartemen lebih kepada durasi ataupun jarak ke Subway bukan pada nama stasiun Subway tersebut.

# %% [markdown]
# ### Drop kolom yang tidak dibutuhkan

# %% [markdown]
# Data set sebelum penghapusan kolom SubwayStation

# %%
j.head()
# Out:
#   HallwayType TimeToSubway          SubwayStation  N_FacilitiesNearBy(ETC)  \
# 0  terraced    0-5min       Kyungbuk_uni_hospital  0.0
# 1  terraced    10min~15min  Kyungbuk_uni_hospital  1.0
# 2  mixed       15min~20min  Chil-sung-market       1.0
# 3  mixed       5min~10min   Bangoge                5.0
# 4  terraced    0-5min       Sin-nam                0.0
#
#    N_FacilitiesNearBy(PublicOffice)  N_SchoolNearBy(University)  \
# 0  3.0                               2.0
# 1  5.0                               1.0
# 2  7.0                               3.0
# 3  5.0                               4.0
# 4  1.0                               2.0
#
#    N_Parkinglot(Basement)  YearBuilt  N_FacilitiesInApt  Size(sqf)  SalePrice
# 0  1270.0                  2007       10                 1387       346017
# 1  0.0                     1986       4                  914        150442
# 2  56.0                    1997       5                  558        61946
# ...

# %% [markdown]
# Data set setelah menghapus kolom SubwayStation

# %%
j = j.drop(columns=['SubwayStation'])
print("DataFrame setelah penghapusan kolom 'SubwayStation':")
display(j.head())
# Out:
# DataFrame setelah penghapusan kolom 'SubwayStation':
#   HallwayType TimeToSubway  N_FacilitiesNearBy(ETC)  \
# 0  terraced    0-5min       0.0
# 1  terraced    10min~15min  1.0
# 2  mixed       15min~20min  1.0
# 3  mixed       5min~10min   5.0
# 4  terraced    0-5min       0.0
#
#    N_FacilitiesNearBy(PublicOffice)  N_SchoolNearBy(University)  \
# 0  3.0                               2.0
# 1  5.0                               1.0
# 2  7.0                               3.0
# 3  5.0                               4.0
# 4  1.0                               2.0
#
#    N_Parkinglot(Basement)  YearBuilt  N_FacilitiesInApt  Size(sqf)  SalePrice
# 0  1270.0                  2007       10                 1387       346017
# 1  0.0                     1986       4                  914        150442
# 2  56.0                    1997       5                  558        61946
# 3  798.0                   2005       7                  914        165486
# ...

# %% [markdown]
# ## Feature Engineering
#
# Secara garis besar terdapat dua tujuan dari feature engineering yakni mempersiapkan dataset yang kompatibel dengan algoritma machine learning yang digunakan dan meningkatkan performa dari sebuah model machine learning.
#
# Melakukan encoding
# Di dalam dataset yang digunakan terdapat beberapa fitur yang memiliki tipe data Object, agar dapat digunakan di dalam model machine learning maka fitur-fitur tersebut akan kita ubah (encoding).
#
# pada tahapan Feature Selection telah dilakukan sebelumnya encoding berjenis Laber Encoders pada saat pengujian Korelasi Semua Kolom karena data yang diterima tidak dapat dilakukan pengujian secara langsung dengan Heatmap karena adanya kolom kategorik yang digabung ke dalam Heatmap numerik sehingga kolom kategorik diubah terlebih dahulu ke bentuk numerik kemudian dapat secara keseluruhan di gambarkan Heatmap Correlation nya
#
# selanjutnya, dilakukan kembali encoding untuk keperluan Modelling. encoding yang tepat dalam case ini adalah menggunakan OneHot Encoding. hal ini karena pada kolom kategori tidak memiliki urutan tertentu dan hanya sedikit data value yang akan di encoding

# %%
d_encoded = pd.get_dummies(j, columns=['HallwayType', 'TimeToSubway']) # perlakuan one hot encoding pada data frame
display(d_encoded)
# Out:
#       N_FacilitiesNearBy(ETC)  N_FacilitiesNearBy(PublicOffice)  \
# 0     0.0                      3.0
# 1     1.0                      5.0
# 2     1.0                      7.0
# 3     5.0                      5.0
# 4     0.0                      1.0
# ...   ...                      ...
# 4116  0.0                      1.0
# 4117  5.0                      6.0
# 4118  0.0                      3.0
# 4119  5.0                      6.0
# 4121  2.0                      5.0
#
#       N_SchoolNearBy(University)  N_Parkinglot(Basement)  YearBuilt  \
# 0     2.0                         1270.0                  2007
# 1     1.0                         0.0                     1986
# 2     3.0                         56.0                    1997
# 3     4.0                         798.0                   2005
# 4     2.0                         536.0                   2006
# ...   ...                           ...                    ...
# ...

# %% [markdown]
# Mengubah type data boolean menjadi integer

# %%
o = d_encoded.astype(int)
o
# Out:
#       N_FacilitiesNearBy(ETC)  N_FacilitiesNearBy(PublicOffice)  \
# 0     0                        3
# 1     1                        5
# 2     1                        7
# 3     5                        5
# 4     0                        1
# ...  ..                       ..
# 4116  0                        1
# 4117  5                        6
# 4118  0                        3
# 4119  5                        6
# 4121  2                        5
#
#       N_SchoolNearBy(University)  N_Parkinglot(Basement)  YearBuilt  \
# 0     2                           1270                    2007
# 1     1                           0                       1986
# 2     3                           56                      1997
# 3     4                           798                     2005
# 4     2                           536                     2006
# ...  ..                           ...                      ...
# 4116  2                           536                     2006
# ...

# %% [markdown]
# Memvisualisasikan kembali korelasi yang terbentuk setelah penggunaan One Hot Encoding

# %%
plt.figure(figsize=(15, 12))
palette=sns.diverging_palette(20, 220, n=256)
corr = o.corr(method='spearman')
sns.heatmap(corr, annot=True, fmt='.2f', cmap=palette, square=True, linewidths=.5)
plt.title('Correlation Matrix after OHE', size=15, weight='bold');

# %% [markdown]
# # MODELLING

# %%
# !pip install category_encoders
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 2.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# Model yang akan digunakan untuk memprediksi nilai Price disini ada 12, terdiri dari 8 base model dan 4 model ensemble, yang kemudian dipilih salah satu model terbaik. Model tersebut adalah:
#
# Base Model:
# 1. Linear Regression
# 2. Polynomial Regression
# 3. Kernel Regression
# 4. KNN Regressor
# 5. Decision Tree Regressor
# 6. Lasso Regression
# 7. Rigde Regression
# 8. Elastic Net
#
# Ensemble Model:
# 9. Random Forest Regressor
# 10. Ada Boost Regressor
# 11. Gradient Boosting Regressor
# 12. Xtreme Gradient Boosting Regessor

# %% [markdown]
# Mengimpor pustaka

# %%
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, GridSearchCV, KFold

import category_encoders as ce
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Import Libraries for modelling
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import LinearRegression, ElasticNet, Lasso, Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from xgboost.sklearn import XGBRegressor


# Import library for tranformed data's features
from sklearn.compose import TransformedTargetRegressor

# Import Matrix for evaluation
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %% [markdown]
# Encoding (OneHot Encoding)

# %%
transformer = ColumnTransformer([
    ('One Hot', OneHotEncoder(drop='first'), ['HallwayType_corridor', 'HallwayType_mixed',	'HallwayType_terraced',	'TimeToSubway_0-5min',	'TimeToSubway_10min~15min',	'TimeToSubway_15min~20min',	'TimeToSubway_5min~10min',	'TimeToSubway_no_bus_stop_nearby']),
], remainder='passthrough')

# %% [markdown]
# Persiapan pemodelan dan pembagian data training dan testing dengan perbadingan 80:20

# %%
x = o.drop(['SalePrice'], axis=1)
y = o['SalePrice']

# %%
# Splitting data training dan test dengan proporsi 80:20
x_train, x_test, y_train, y_test= train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=1)

# %% [markdown]
# ### Matrix Comparison

# %% [markdown]
# Melakukan pemodelan setiap jenis model dengan menggunakan data set. selanjutnya dilakukan perbandingan menggunakan Evaluation Matrics untuk setiap model yang telah dibuat menggunakan Evaluation Matrics: MSE, RMSE, MAE, MAPE dan R-Squared.

# %%
# Define Models Algoritm
LR = LinearRegression()
Poly = Pipeline([('poly', PolynomialFeatures(degree=2)),('linear', LinearRegression())])
KRR = KernelRidge()
KNN = KNeighborsRegressor()
DTR = DecisionTreeRegressor(random_state=1)
LS = Lasso(alpha =0.05, random_state=1) # alpha kecil agar fiturnya banyak
RR = Ridge(alpha =0.05)
EN = ElasticNet(random_state=1, alpha =0.025) # alpha Lasso-Ridge
RFR = RandomForestRegressor(random_state=1)
ABR = AdaBoostRegressor(random_state=1)
GB = GradientBoostingRegressor(random_state=1)
XGB = XGBRegressor(random_state=1)

# Scale models to logaricmic and transform to original (normalize)
log_LR = TransformedTargetRegressor(LR, func=np.log, inverse_func=np.exp)
log_Poly = TransformedTargetRegressor(Poly, func=np.log, inverse_func=np.exp)
log_KRR = TransformedTargetRegressor(KRR, func=np.log, inverse_func=np.exp)
log_KNN = TransformedTargetRegressor(KNN, func=np.log, inverse_func=np.exp)
log_DTR = TransformedTargetRegressor(DTR, func=np.log, inverse_func=np.exp)
log_LS = TransformedTargetRegressor(LS, func=np.log, inverse_func=np.exp)
log_RR = TransformedTargetRegressor(RR, func=np.log, inverse_func=np.exp)
log_EN = TransformedTargetRegressor(EN, func=np.log, inverse_func=np.exp)
log_RFR = TransformedTargetRegressor(RFR, func=np.log, inverse_func=np.exp)
log_ABR = TransformedTargetRegressor(ABR, func=np.log, inverse_func=np.exp)
log_GB = TransformedTargetRegressor(GB, func=np.log, inverse_func=np.exp)
log_XGB = TransformedTargetRegressor(XGB, func=np.log, inverse_func=np.exp)

# Scaling data
scaler = StandardScaler()

# Models list
models = [log_LR, log_Poly, log_KRR, log_KNN, log_DTR, log_LS, log_RR, log_EN, log_RFR, log_ABR, log_GB, log_XGB]

# Each Matrix score stores in the list
score_r2 = []
nilai_mean_r2 = []
nilai_std_r2 = []

score_mse = []
nilai_mean_mse = []
nilai_std_mse = []

score_rmse = []
nilai_mean_rmse = []
nilai_std_rmse = []

score_mae = []
nilai_mean_mae = []
nilai_std_mae = []

score_mape = []
nilai_mean_mape = []
nilai_std_mape = []

# Finding best model's matrix score
for i in models:

    crossval = KFold(n_splits=5, shuffle=True, random_state=1)

    estimator = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', i)
    ])


    # r2
    model_cv_r2 = cross_val_score(
        estimator,
        x_train,
        y_train,
        cv=crossval,
        scoring='r2',
        error_score='raise'
        )

    print(model_cv_r2, i)

    score_r2.append(model_cv_r2)
    nilai_mean_r2.append(model_cv_r2.mean())
    nilai_std_r2.append(model_cv_r2.std())

    # MSE
    model_cv_mse = cross_val_score(
        estimator,
        x_train,
        y_train,
        cv=crossval,
        scoring='neg_mean_squared_error',
        error_score='raise'
        )

    print(model_cv_mse, i)

    score_mse.append(model_cv_mse)
    nilai_mean_mse.append(model_cv_mse.mean())
    nilai_std_mse.append(model_cv_mse.std())

    # RMSE
    model_cv_rmse = cross_val_score(
        estimator,
        x_train,
        y_train,
        cv=crossval,
        scoring='neg_root_mean_squared_error',
        error_score='raise'
        )

    print(model_cv_rmse, i)

    score_rmse.append(model_cv_rmse)
    nilai_mean_rmse.append(model_cv_rmse.mean())
    nilai_std_rmse.append(model_cv_rmse.std())

    # MAE
    model_cv_mae = cross_val_score(
        estimator,
        x_train,
        y_train,
        cv=crossval,
        scoring='neg_mean_absolute_error',
        error_score='raise'
        )

    print(model_cv_mae, i)

    score_mae.append(model_cv_mae)
    nilai_mean_mae.append(model_cv_mae.mean())
    nilai_std_mae.append(model_cv_mae.std())

    # MAPE
    model_cv_mape = cross_val_score(
        estimator,
        x_train,
        y_train,
        cv=crossval,
        scoring='neg_mean_absolute_percentage_error',
        error_score='raise'
        )

    print(model_cv_mape, i)

    score_mape.append(model_cv_mape)
    nilai_mean_mape.append(model_cv_mape.mean())
    nilai_std_mape.append(model_cv_mape.std())
# Out:
# [0.72674234 0.74541254 0.74687478 0.73068067 0.71180883] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-3.01613818e+09 -2.82296160e+09 -2.80614469e+09 -2.83605220e+09
#  -3.13311660e+09] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-54919.37892757 -53131.54991401 -52973.05622526 -53254.59795468
#  -55974.24943651] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-44239.87184649 -42573.29769449 -41863.83220243 -43315.10922944
#  -44713.59119011] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-0.22196689 -0.22080563 -0.21689176 -0.22136012 -0.21668296] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
# ...

# %% [markdown]
# Menampilkan hasil komparasi dengan Evaluation Matrics

# %%
# Model Matrix Evaluation
model_evaluation = pd.DataFrame({
    'Model': ['Linear Regression', 'Polynomial Regression', 'Kernel Regression', 'KNN Regressor', 'Decision Tree Regressor', 'Lasso Regression', 'Rigde Regression', 'Elastic Net', 'Random Forest Regressor', 'Ada Boost Regressor', 'Gradient Boosting Regressor', 'Xtreme Gradient Boosting Regessor'],
    'Mean_MSE': nilai_mean_mse,
    'Std_MSE': nilai_std_mse,
    'Mean_RMSE': nilai_mean_rmse,
    'Std_RMSE': nilai_std_rmse,
    'Mean_MAE': nilai_mean_mae,
    'Std_MAE': nilai_std_mae,
    'Mean_MAPE': nilai_mean_mape,
    'Std_MAPE': nilai_std_mape,
    'Mean_R2': nilai_mean_r2,
    'Std_R2': nilai_std_r2
})
model_evaluation
# Out:
#                                 Model      Mean_MSE       Std_MSE  \
# 0   Linear Regression                 -2.922883e+09  1.296506e+08
# 1   Polynomial Regression             -5.325929e+10  1.016590e+11
# 2   Kernel Regression                 -6.183751e+10  1.524847e+09
# 3   KNN Regressor                     -2.421048e+09  1.545910e+08
# 4   Decision Tree Regressor           -2.135513e+09  1.830424e+08
# 5   Lasso Regression                  -3.044142e+09  1.657862e+08
# 6   Rigde Regression                  -2.920590e+09  1.267859e+08
# 7   Elastic Net                       -2.991851e+09  1.331472e+08
# 8   Random Forest Regressor           -2.113260e+09  1.793665e+08
# 9   Ada Boost Regressor               -3.162411e+09  2.488220e+08
# 10  Gradient Boosting Regressor       -2.092009e+09  1.791972e+08
# 11  Xtreme Gradient Boosting Regessor -2.119714e+09  1.762438e+08
#
#         Mean_RMSE       Std_RMSE       Mean_MAE       Std_MAE  Mean_MAPE  \
# ...

# %% [markdown]
# ## Benchmarking Model

# %% [markdown]
# 1. Benchmarking dengan data train

# %% [markdown]
# Dari hasil perbandingan (benchmarking model) menggunakan data train diatas dapat dilihat bahwa Matric yang terbentuk menunjukan Model yang memiliki keunggulan/keakuratan dibanding yang lain. berikut hasilnya:
# 1. MSE: Gradient Boosting Regressor
# 2. RMSE: Gradient Boosting Regressor
# 3. MAE: Random Forest Regressor
# 4. MAPE: Gradient Boosting Regressor
# 5. R-Squared: Gradient Boosting Regressor
#
# dari hasil ini menunjukan bahwa Gradient Boosting Regressor memiliki nilai error terbaik dari semua model khususnya dari evaluasi matric MSE, RMSE, MAPE, R2. sedangkan pada evaluasi matric MAE menunjukan bahwa Random Forest Regressor memiliki nilai error terkecil (36.394)sedikit lebih baik dari Gradient Boosting Regressor (36.400) pada evaluasi matric yang sama.
#
# selanjutnya kita akan membandingkan antara kedua model tersebut dengan menggunakan metode cross validation dan menggunakan data train serta evaluation matric hanya RMSE (karena Gradient Boosting Regressor) dan MAE (karena Random Forest Regressor).

# %%
model_Bench = {
    'Random Forest Regression': RandomForestRegressor(random_state=1),
    'Gradient Boosting Regression': GradientBoostingRegressor(random_state=1),
}

# %%
cv_scores_rmse = {}
cv_scores_mae = {}

for name, model in model_Bench.items():
    cv_rmse = cross_val_score(model, x_train, y_train, cv=5, scoring='neg_root_mean_squared_error')
    cv_scores_rmse[name] = -np.mean(cv_rmse)

    cv_mae = cross_val_score(model, x_train, y_train, cv=5, scoring='neg_mean_absolute_error')
    cv_scores_mae[name] = -np.mean(cv_mae)


for name, score in cv_scores_rmse.items():
    print(f'Average RMSE for {name} after cross-validation: {score}')

for name, score in cv_scores_mae.items():
    print(f'Average MAE for {name} after cross-validation: {score}')
# Out:
# Average RMSE for Random Forest Regression after cross-validation: 46238.12353737579
# Average RMSE for Gradient Boosting Regression after cross-validation: 45892.46870670775
# Average MAE for Random Forest Regression after cross-validation: 37047.994261345455
# Average MAE for Gradient Boosting Regression after cross-validation: 36948.05315658895

# %% [markdown]
# Cross Validation menggunakan data test

# %%
cv_scores_rmse = {}
cv_scores_mae = {}

for name, model in model_Bench.items():
    cv_rmse = cross_val_score(model, x_test, y_test, cv=5, scoring='neg_root_mean_squared_error')
    cv_scores_rmse[name] = -np.mean(cv_rmse)

    cv_mae = cross_val_score(model, x_test, y_test, cv=5, scoring='neg_mean_absolute_error')
    cv_scores_mae[name] = -np.mean(cv_mae)


for name, score in cv_scores_rmse.items():
    print(f'Average RMSE for {name} after cross-validation: {score}')

for name, score in cv_scores_mae.items():
    print(f'Average MAE for {name} after cross-validation: {score}')
# Out:
# Average RMSE for Random Forest Regression after cross-validation: 50797.60708267019
# Average RMSE for Gradient Boosting Regression after cross-validation: 49965.091482051255
# Average MAE for Random Forest Regression after cross-validation: 41153.18621722461
# Average MAE for Gradient Boosting Regression after cross-validation: 40473.97016957113

# %% [markdown]
# Dari hasil diatas dapat dilihat bahwa terjadi penurunan nilai error masing-masing model setelah cross validation namun nilai ini lebih tinggi dibandikan dengan menggunakan data train sehingga tetap kita gunakan data train

# %% [markdown]
# selanjutnya dapat divisualisasikan menggunakan Learning Curve untuk memeriksa apakah model terdapat Overfitting

# %%
from sklearn.model_selection import learning_curve

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
plot_learning_curve(model, "Learning Curve", x_train, y_train, cv=5)
plt.show()

# %% [markdown]
# Dari hasil diatas diketahui bahwa model tidak terjadi overfitting

# %% [markdown]
# Selanjutnya dicoba untuk melakukan Benchmark 2 model terbaik dengan menggunakan Evaluation Matric hanya RMSE, MAE dan R-Squared saja dan akan disimpan sebagai model sebelum dilakukan tunning

# %%
score_mse = []
score_rmse = []
score_mae = []
score_mape = []
score_r2 = []

# Prediksi pada test set
for i in model_Bench:

    model = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', model_Bench[i])
        ])

    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)

    score_rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    score_mae.append(mean_absolute_error(y_test, y_pred))
    score_r2.append(r2_score(y_test, y_pred))


score_before_tuning = pd.DataFrame({'RMSE': score_rmse, 'MAE': score_mae,'R2': score_r2}, index=model_Bench.keys())
score_before_tuning
# Out:
#                                       RMSE           MAE        R2
# Random Forest Regression      46698.966166  37894.708696  0.804127
# Gradient Boosting Regression  46339.482362  37716.634640  0.807131

# %% [markdown]
# Kesimpulan dari hal ini didapatkan bahwa model yang terpilih adalah Gradient Boosting Regression dengan nilai RMSE, MAE dan R-Squared yang terbaik dari Random Forest Regression

# %% [markdown]
# # EVALUATION

# %% [markdown]
# ## Hyperparameter Tunning

# %% [markdown]
# 1. Grid Search

# %%
gbr_sklearn = GradientBoostingRegressor()
param_grid = {
    'n_estimators': [300, 400],
    'learning_rate': [0.05],
    'max_depth': [3],
    'min_samples_split': [10, 15],
    'min_samples_leaf': [1]
}

grid_search = GridSearchCV(estimator=gbr_sklearn, param_grid=param_grid, cv=5, scoring='r2')
grid_search.fit(x_train, y_train)

best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

# %%
best_estimator.fit(x_train, y_train)
test_score = best_estimator.score(x_test, y_test)

y_pred_grid = best_estimator.predict(x_test)
mae = mean_absolute_error(y_test, y_pred_grid)
rmse = mean_squared_error(y_test, y_pred_grid, squared=False)
r2_ = r2_score(y_test, y_pred_grid)

print("Best Hyperparameters:", best_params)
print("R-Squared (R2):", r2_)
print("Mean Absolute Error (MAE):", mae)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Best Hyperparameters: {'learning_rate': 0.05, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 15, 'n_estimators': 300}
# R-Squared (R2): 0.8071830685175123
# Mean Absolute Error (MAE): 37736.72530588422
# Root Mean Squared Error (RMSE): 46333.2169264815

# %% [markdown]
# pada hyperparameter tunnning menggunakan Grid Search ini didapatkah hasil diatas

# %% [markdown]
# 2. Randomized search

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import RandomizedSearchCV

parameter = {
    'n_estimators': [300, 400, 500],
    'learning_rate': [0.05],
    'max_depth': [3],
    'min_samples_split': [10, 15, 20],
    'min_samples_leaf': [1,3,5]
}

mode = GradientBoostingRegressor(random_state=1)
random_search = RandomizedSearchCV(estimator=mode, param_distributions=parameter, n_iter=50,
                                   scoring='r2', cv=5, random_state=1)

random_search.fit(x_train, y_train)
test_score_random = random_search.score(x_test, y_test)

y_pred_random = random_search.predict(x_test)
mae_random = mean_absolute_error(y_test, y_pred_random)
rmse_random = mean_squared_error(y_test, y_pred_random, squared=False)
r2_random = r2_score(y_test, y_pred_random)

print("Best params:", random_search.best_params_)
print('R-Squared (R2):',r2_random)
print('Mean Absolute Error (MAE):',mae_random)
print('Root Mean Squared Error (RMSE):',rmse_random)
# Out:
# Best params: {'n_estimators': 300, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.05}
# R-Squared (R2): 0.8071830685175123
# Mean Absolute Error (MAE): 37736.72530588421
# Root Mean Squared Error (RMSE): 46333.2169264815

# %% [markdown]
# pada hyperparameter tunnning menggunakan Randomized Search ini didapatkah hasil diatas.
#
# hasil dari kedua metode tidak terdapat perbedaan karena best parameter yang didapatkan menunjukan hasil yang sama
#
# selanjutnya, dibuat score after tunning

# %%
# Model GBoost
model_GBR = {'Gradient Boosting Regression': GradientBoostingRegressor(random_state=1)}

# Define model terhadap estimator terbaik
gbr_tuning = random_search.best_estimator_

# Fitting model
gbr_tuning.fit(x_train, y_train)

# Predict test set
y_pred_gbr_tuning = gbr_tuning.predict(x_test)

# Simpan nilai metrics RMSE, MAE, MAPE dan R-Squared setelah tuning
rmse_gbr_tuning = np.sqrt(mean_squared_error(y_test, y_pred_gbr_tuning))
mae_gbr_tuning = mean_absolute_error(y_test, y_pred_gbr_tuning)
r2_gbr_tuning = r2_score(y_test, y_pred_gbr_tuning)

score_after_tuning = pd.DataFrame({'RMSE': rmse_gbr_tuning, 'MAE': mae_gbr_tuning, 'R2': r2_gbr_tuning}, index=model_GBR.keys())
score_after_tuning
# Out:
#                                       RMSE           MAE        R2
# Gradient Boosting Regression  46333.216926  37736.725306  0.807183

# %% [markdown]
# selanjutnya, melakukan perbandinga score antara sebelum tunning dan setelahnya

# %%
gbr_score_before = pd.DataFrame(score_before_tuning.loc['Gradient Boosting Regression']).rename({'Gradient Boosting Regression': 'Sebelum Hyperparameter Tuning'}, axis=1)
gbr_score_after = score_after_tuning.T.rename({'Gradient Boosting Regression': 'Sesudah Hyperparameter Tuning'}, axis=1)

matrix_compare_gbr = pd.concat([gbr_score_before, gbr_score_after], axis=1)

matrix_compare_gbr['Persentase peningkatan (%)'] = (matrix_compare_gbr['Sebelum Hyperparameter Tuning']-matrix_compare_gbr['Sesudah Hyperparameter Tuning'])*100/matrix_compare_gbr['Sebelum Hyperparameter Tuning']

matrix_compare_gbr
# Out:
#       Sebelum Hyperparameter Tuning  Sesudah Hyperparameter Tuning  \
# RMSE  46339.482362                   46333.216926
# MAE   37716.634640                   37736.725306
# R2    0.807131                       0.807183
#
#       Persentase peningkatan (%)
# RMSE  0.013521
# MAE  -0.053267
# R2   -0.006461

# %% [markdown]
# dari hasil tunning diatas dapat dilihat bahwa tidak terjadi perbedaan yang signifikan terhadap score yang didapat bahkan terdapat penurunan performa yang sangat kecil setelah dilakukan tunning pada evaluation matric MAE.

# %%
plt.figure(figsize=(10, 10))
plot = sns.scatterplot(x=y_test, y=y_pred_gbr_tuning).set(title='Actual vs. Prediction Price',
                                               xlabel='Actual Price',
                                               ylabel='Predicted Price');

# %% [markdown]
# dari tampilan visualisasi diatas dapat dilihat bahwa grafik scatter plot menunjukan hubungan regresi yang cukup baik antara harga prediksi dengan actual nya

# %% [markdown]
# Selanjutnya dilakukan interpretasi model
#
# Interpretasi model merupakan langkah penting dalam analisis data dan pembuatan keputusan karena memberikan pemahaman yang mendalam tentang bagaimana model bekerja dan faktor-faktor apa yang mempengaruhi prediksi yang dihasilkan.

# %% [markdown]
# ## Feature Importance
#
# Feature Importance Analysis adalah proses yang penting dalam pemodelan data untuk memahami kontribusi masing-masing fitur terhadap prediksi atau hasil yang diinginkan.

# %%
importance = best_estimator.feature_importances_

feature_importance_df = pd.DataFrame({'Feature': x.columns, 'Importance': importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

display(feature_importance_df)
# Out:
#                              Feature  Importance
# 9   HallwayType_terraced              0.401729
# 6   Size(sqf)                         0.324998
# 4   YearBuilt                         0.097981
# 3   N_Parkinglot(Basement)            0.081793
# 0   N_FacilitiesNearBy(ETC)           0.045625
# 5   N_FacilitiesInApt                 0.032077
# 1   N_FacilitiesNearBy(PublicOffice)  0.005394
# 7   HallwayType_corridor              0.004612
# 2   N_SchoolNearBy(University)        0.003111
# 10  TimeToSubway_0-5min               0.001258
# 14  TimeToSubway_no_bus_stop_nearby   0.000716
# 8   HallwayType_mixed                 0.000470
# 13  TimeToSubway_5min~10min           0.000133
# 11  TimeToSubway_10min~15min          0.000100
# 12  TimeToSubway_15min~20min          0.000003

# %%
importance = best_estimator.feature_importances_

indices = np.argsort(importance)

plt.figure(figsize=(10, 6))
plt.title('Feature Importance')
plt.barh(range(len(indices)), importance[indices], color='b', align='center')
plt.yticks(range(len(indices)), [x_train.columns[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# Dari hasil grafik diatas, fitur hallway bertipe teras adalah fitur paling penting dalam menentukan harga penjualan apartemen, diikuti oleh Luasan dalam square-feet, dan yang terpenting ketiga adalah tahun kapan dibangun. Fitur lain juga berkontribusi pada model, meskipun dalam tingkat yang lebih rendah.
#
# Namun untuk mendapatkan insight lebih lanjut, yaitu bagaimana pengaruh dari fitur tersebut terhadap prediksi harga perlu dilakukan analisis SHAP untuk melihat seberapa besar kontribusi terhadap harga dan apakah ter polarisasi positif ataupun negatif

# %% [markdown]
# ## SHAP (SHapley Additive exPlanations) Values

# %% [markdown]
# Penjelasan Grafik SHAP Beeswarm
#
# Sumbu:
#
# Sumbu x mewakili nilai SHAP, yang menunjukkan dampak setiap fitur pada output model. Nilai SHAP bisa positif atau negatif, menunjukkan seberapa besar kontribusi fitur tertentu dalam meningkatkan atau menurunkan prediksi.
# Sumbu y mencantumkan fitur-fitur yang digunakan dalam model, diurutkan berdasarkan kepentingannya (nilai absolut rata-rata dari nilai SHAP-nya).
# Warna:
# Warna titik-titik menunjukkan nilai fitur, dengan gradasi dari biru (nilai rendah) ke merah (nilai tinggi). Ini membantu memahami hubungan antara nilai fitur dan dampaknya pada prediksi.
#
# Distribusi Titik:
#
# Setiap titik pada plot mewakili satu prediksi dari dataset. Posisi titik sepanjang sumbu x menunjukkan nilai SHAP untuk fitur dan instance tersebut.
# Distribusi titik yang lebih lebar sepanjang sumbu x menunjukkan bahwa fitur tersebut memiliki dampak yang lebih signifikan pada prediksi model.

# %%
# !pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.5/540.5 kB 11.5 MB/s eta 0:00:00
# ...

# %%
# Membuat SHAP explainer
import shap
explainer = shap.TreeExplainer(best_estimator)
shap_values = explainer.shap_values(x_train)
shap.summary_plot(shap_values, x_train)

# %% [markdown]
# ## hubungan evaluation metrics dengan aspek bisnis

# %% [markdown]
# Grafik SHAP beeswarm ini memberikan visualisasi komprehensif tentang pentingnya fitur dan dampaknya terhadap prediksi model. Berikut adalah penjelasan rinci tentang grafik ini:
#
# - Pengamatan Utama berdasarkan 3 fitur terpenting
#
#   - *Feature importance*:
#       - **Size(Sqf)**: Fitur ini memiliki dampak yang signifikan pada prediksi model. Luasan dalam kaki-persegi memiliki nilai tinggi (merah) umumnya meningkatkan nilai prediksi, sedangkan Luasan dalam kaki-persegi rendah (biru) akan menurunkannya. dalam arti, semakin tinggi dan positif nilainya maka akan menaikan nilai prediksi harganya.
#       - **HallwayType_Terraced**: Fitur ini memiliki dampak yang paling signifikan pada prediksi model. walaupun ini adalah fitur yang paling penting namun seberapa besar nilai dampaknya tidak sebesar pada fitur Size(sqf) dan Year(built). fitur ini terpenting karena jika apartemen memiliki teras, maka akan menaikan minat para calon pembeli namun harganya tidak sesignifikan naik pada harga prediksi seperti pada ukuran dan tahun bangun. meskipun begitu fitur ini tetap memiliki dampak pada harga jual, semakin tinggi dan positif nilainya maka akan menaikan nilai prediksi harganya.
#       - **YearBuilt**: Fitur ini memiliki dampak yang juga signifikan pada prediksi model. tahun bangun memiliki nilai tinggi (merah) umumnya meningkatkan nilai prediksi, sedangkan tahun bangun yang rendah (biru) akan menurunkannya. dalam arti, semakin tinggi (baru) dan positif nilainya maka akan menaikan nilai prediksi harganya
#
#   - *Feature impact*:
#       - **Size(Sqf)**: ukuran apartemen yang lebih luas memiliki dampak positif yang kuat pada output prediksi.
#       - **HallwayType_Terraced**: apartemen yang diberikan teras dibandingkan yang tidak cenderung menaikan nilai prediksi, seperti hal nya fitur ukuran.
#       - **YearBuilt**: apartemen yang dibangun lebih baru dibandingkan yang telah lama akan menaikan nilai prediksi, seperti hal nya fitur yang lain.
#
# - Ringkasan
#
# Plot SHAP beeswarm ini memberikan pandangan mendetail tentang bagaimana setiap fitur berkontribusi pada prediksi model. Fitur seperti **Size(sqf)**, **HallwayType_Terraced** dan **YearBuilt** memiliki dampak signifikan, dengan nilai **Size(sqf)** yang tinggi secara kuat meningkatkan prediksi. Gradasi warna membantu dalam memahami efek dari berbagai nilai fitur pada prediksi.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# 1. Kesimpulan model

# %%
y_test.reset_index(drop=True, inplace=True)

actual_50 = y_test[:50]
pred_50 = y_pred[:50]

plt.figure(figsize=(10, 6))
plt.plot(actual_50, label='Actual', marker='o')
plt.plot(pred_50, label='Predicted', marker='x')
plt.title('Comparison of Actual and Predicted Values')
plt.xlabel('Data Point')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# Berikut adalah perbandingan antara hasil prediksi model dan data aktual. dapat dilihat bahwa model dapat memprediksi estimasi harga jual cukup akurat.
#
# Berikut adalah rangkuman dari pemodelan yang telah dibentuk:
# 1. Pemilihan Model Terbaik: Dari 12 model yang dievaluasi, model terbaik dipilih berdasarkan metrik MSE, RMSE, MAE, MAPE dan R<sup>2</sup>. Model yang dipilih adalah Gradient Boosting Regressor.
#
# - Parameter Hyperparameter Terbaik:
#   - learning_rate: 0.05
#   - max_depth: 3
#   - n_estimators: 300
#   - min_samples_leaf: 1
#   - min_samples_split: 15
#
# - Kinerja Model pada Data Uji:
#   - Skor R<sup>2</sup>: **0.8071830685175123**,
#   menunjukkan bahwa model dapat memprediksi sekitar 80.71% variabilitas dalam harga apartemen di Daegu, mengindikasikan hubungan yang kuat antara variabel independen (fitur) dan variabel dependen (harga rumah). Ini menunjukkan bahwa prediksi model sangat akurat dan andal, sehingga berguna untuk memprediksi nilai rumah.
#   - Mean Absolute Error (MAE): **37736.72530588421**,
#   menunjukkan rata-rata kesalahan absolut prediksi harga apartemen adalah sekitar 37.736 Won. Nilai MAE yang lebih rendah diinginkan, dan 37.736 Won adalah relatif rendah, mengindikasikan bahwa prediksi model umumnya dekat dengan harga sebenarnya.
#   - Root Mean Squared Error (RMSE): **46333.2169264815**,
#   menunjukkan akar kuadrat dari rata-rata kesalahan kuadrat prediksi harga apartemen adalah sekitar 46.333 Won. Mirip dengan MAE, nilai RMSE yang lebih rendah diinginkan, dan 46.333 Won adalah relatif rendah, mengindikasikan bahwa prediksi model memiliki dispersi atau penyebaran yang rendah di sekitar harga sebenarnya.
#
# - Model Gradient Boosting Regressor yang dipilih menunjukkan performa yang baik dengan R2 yang tinggi, mengindikasikan prediksi harga apartemen yang cukup akurat.
# - Nilai MAE dan RMSE menunjukkan tingkat kesalahan yang dapat diterima mengingat kompleksitas dan variabilitas harga apartemen di Daegu.

# %% [markdown]
# 2. Kelemahan model

# %% [markdown]
# Dari hasil hyperparameter tunning menunjukan perubahan score yang tidak signifikan lebih baik dari sebelum tunning sehingga pada masa yang akan datang perlu untuk meningkatkan score setelah tunning dengan metode yang lebih advanced.
#
# Ukuran data pada data set yang digunakan pada model ini terbatas atau dapat dikatakan hanya sedikit dibandingkan rentang waktu yang sangat panjang (sejak tahun dibangunnya apartemen yang sudah tua) sehingga ukuran data yang lebih kecil dibandingkan penggunaan model untuk memprediksi pada jangka waktu yang panjang ke masa depan akan menurunkan performa akurasi model jika ukuran data set model < perkembangan data set kemasa berikutnya.
#
# Model ini tidak dapat digunakan jika terdapat perubahan faktor eksternal yang secara aktualnya dapat mempengaruhi harga jual yang terjadi dilapangan, selain itu, kenaikan harga jual apartemen dari tahun ke tahun tidak dapat diprediksi jika tidak ada fitur yang berpengaruh terhadap pertumbuhan harga jual seperti inflasi, demografi, pajak dan sebagainya karena keterbatasan fitur yang digunakan pada model ini.

# %% [markdown]
# 3. Kesimpulan Bisnis
#
# jika sebelumnya dengan begitu cukup sulit bagi pemilik apartemen untuk menyesuaikan dengan harga pasar. Jika harganya terlalu tinggi dibandingkan dengan harga pasar, tentu akan sulit untuk melakukan penjualan. Sebaliknya, jika terlalu rendah, pemilik akan sulit mendapatkan keuntungan yang maksimal maka dengan adanya Machine Learning yang dibuat ini dapat memberikan harga yang cukup akurat dengan berbagai fitur yang di perhitungkan saat ini dengan estimasi rata-rata selisih akurasi harga jual hanya 37.736 Won.

# %% [markdown]
# # RECOMMENDATION

# %% [markdown]
# 1. Rekomendasi model:
#
# Melakukan Iterative Feature Selection, Kelebihan dari Iterative Feature Selection adalah lebih banyak kombinasi model yang kita coba. Metode ini berpotensi untuk dapat mengungguli metode feature selection lainnya untuk mendapatkan model yang lebih baik.
#
# Penambahan ukuran data set serta fitur yang Lebih Komprehensif dapat meningkatkan akurasi dan masa pakai dari model yang dibuat. Menambahkan lebih banyak fitur relevan terkait harga apartemen dapat membantu meningkatkan akurasi model. Penambahan fitur-fitur yang relevan juga perlu mempertimbangkan dinamika faktor internal maupun eksternal yang dapat berubah setiap saat sesuai prinsip jual beli properti hunian seperti apartemen.
#
# selain itu, model yang telah dibuat hendaknya dapat dilakukan update data secara periodik dan perlakuan hyperparameter tunning kembali.
#
#
# 2. Rekomendasi bisnis dan Estimasi keuntungan bisnis
#
#
# Selain keuntungan yang akan didapatkan pada penawar adalah berkurangnya biaya dan waktu untuk melakukan estimasi harga apartemen di Daegu yang ingin tawarkan kepada calon pembeli, estimasi keuntungan bagi bisnis karena penerapan Machine Learning ini adalah maksimum profit bagi penjual apartemen.
#
# Berdasarkan fakta Saat ini bahwa Daegu merupakan wilayah metropolitan terbesar ke-4 dalam hal populasi dan masih menjadi kota perdagangan terbesar ke-3 di Korea Selatan selain itu, kelompok usia dewasa muda menjadi kelompok usia paling mendominasi dibandingkan kelompok usia lainnya dan Kelompok usia inilah yang dijadikan target pasar hunian karena minat yang cukup tinggi dalam memiliki hunian sehingga pangsa pasar dan permintaan terhadap kepemilikan apartemen juga tinggi.
#
# jika dalam pemodelan 3 fitur yang paling mempengaruhi pembentukan harga jual yaitu jenis Hallway dengan teras, ukuran apartemen yang luas serta tahun dibangunnya maka rekomendasi bisnis yang dapat diberikan adalah melakukan renovasi terhadap aset yang dimiliki seperti memberikan teras dan membuat tata letak atau layout apartemen terlihat dan terasa luas dan renovasi yang dilakukan tentu akan memperbaharui tahun dibangunnya sehingga akan memaksimalkan profit bagi pemilik aset untuk dijual.
#
# dengan rekomendasi ini diharapakan dapat menyerap potensi besarnya target pasar di kota Daegu serta pemilik aset bisa mendapatkan keuntungan setinggi-tingginya sesuai perubahan/renovasi fitur dalam memprediksi harga jual.

# %% [markdown]
# ======

# %%
import pickle
from google.colab import files

# Langkah 1: Simpan model sebagai file pickle
filename = 'DaeguApartmentModel.pkl'
with open(filename, 'wb') as file:
    pickle.dump(best_estimator, file)
files.download(filename)

# %%
with open(filename, 'rb') as file:
    DaeguModel = pickle.load(file)
